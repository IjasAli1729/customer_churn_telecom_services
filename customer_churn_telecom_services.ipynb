# %%
import pandas as pd

# %%
Data = pd.read_csv(r"C:\Users\Ijas Ali.Machingal\Downloads\customer_churn_telecom_services.csv")

Data
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0     Female              0     Yes         No       1           No
# 1       Male              0      No         No      34          Yes
# 2       Male              0      No         No       2          Yes
# 3       Male              0      No         No      45           No
# 4     Female              0      No         No       2          Yes
# ...      ...            ...     ...        ...     ...          ...
# 7038    Male              0     Yes        Yes      24          Yes
# 7039  Female              0     Yes        Yes      72          Yes
# 7040  Female              0     Yes        Yes      11           No
# 7041    Male              1     Yes         No       4          Yes
# 7042    Male              0      No         No      66          Yes
#
#          MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0     No phone service             DSL             No          Yes
# ...

# %%
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   gender            7043 non-null   object
#  1   SeniorCitizen     7043 non-null   int64
#  2   Partner           7043 non-null   object
#  3   Dependents        7043 non-null   object
#  4   tenure            7043 non-null   int64
#  5   PhoneService      7043 non-null   object
#  6   MultipleLines     7043 non-null   object
#  7   InternetService   7043 non-null   object
#  8   OnlineSecurity    7043 non-null   object
#  9   OnlineBackup      7043 non-null   object
#  10  DeviceProtection  7043 non-null   object
#  11  TechSupport       7043 non-null   object
#  12  StreamingTV       7043 non-null   object
#  13  StreamingMovies   7043 non-null   object
#  14  Contract          7043 non-null   object
#  15  PaperlessBilling  7043 non-null   object
# ...

# %%
Data.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges  TotalCharges
# count    7043.000000  7043.000000     7043.000000   7032.000000
# mean        0.162147    32.371149       64.761692   2283.300441
# std         0.368612    24.559481       30.090047   2266.771362
# min         0.000000     0.000000       18.250000     18.800000
# 25%         0.000000     9.000000       35.500000    401.450000
# 50%         0.000000    29.000000       70.350000   1397.475000
# 75%         0.000000    55.000000       89.850000   3794.737500
# max         1.000000    72.000000      118.750000   8684.800000

# %%
Data.isna().sum()
# Out:
# gender               0
# SeniorCitizen        0
# Partner              0
# Dependents           0
# tenure               0
# PhoneService         0
# MultipleLines        0
# InternetService      0
# OnlineSecurity       0
# OnlineBackup         0
# DeviceProtection     0
# TechSupport          0
# StreamingTV          0
# StreamingMovies      0
# Contract             0
# PaperlessBilling     0
# PaymentMethod        0
# MonthlyCharges       0
# TotalCharges        11
# Churn                0
# dtype: int64

# %%
Data = Data.dropna()

# %%
Data.isna().sum()
# Out:
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %% [markdown]
# ## LABEL ENCODER

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()

# %%
Data['gender'] = encoder.fit_transform(Data['gender'])
Data['Partner'] = encoder.fit_transform(Data['Partner'])
Data['Dependents'] = encoder.fit_transform(Data['Dependents'])
Data['PhoneService'] = encoder.fit_transform(Data['PhoneService'])
Data['MultipleLines'] = encoder.fit_transform(Data['MultipleLines'])
Data['InternetService'] = encoder.fit_transform(Data['InternetService'])
Data['OnlineSecurity'] = encoder.fit_transform(Data['OnlineSecurity'])
Data['OnlineBackup'] = encoder.fit_transform(Data['OnlineBackup'])
Data['DeviceProtection'] = encoder.fit_transform(Data['DeviceProtection'])
Data['TechSupport'] = encoder.fit_transform(Data['TechSupport'])
Data['StreamingTV'] = encoder.fit_transform(Data['StreamingTV'])
Data['StreamingMovies'] = encoder.fit_transform(Data['StreamingMovies'])
Data['Contract'] = encoder.fit_transform(Data['Contract'])
Data['PaperlessBilling'] = encoder.fit_transform(Data['PaperlessBilling'])
Data['PaymentMethod'] = encoder.fit_transform(Data['PaymentMethod'])
Data['Churn'] = encoder.fit_transform(Data['Churn'])
# Out:
# C:\Users\Ijas Ali.Machingal\AppData\Local\Temp\ipykernel_16684\611453075.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Data['gender'] = encoder.fit_transform(Data['gender'])
# C:\Users\Ijas Ali.Machingal\AppData\Local\Temp\ipykernel_16684\611453075.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Data['Partner'] = encoder.fit_transform(Data['Partner'])
# C:\Users\Ijas Ali.Machingal\AppData\Local\Temp\ipykernel_16684\611453075.py:3: SettingWithCopyWarning:
# ...

# %%
Data
# Out:
#       gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 0          0              0        1           0       1             0
# 1          1              0        0           0      34             1
# 2          1              0        0           0       2             1
# 3          1              0        0           0      45             0
# 4          0              0        0           0       2             1
# ...      ...            ...      ...         ...     ...           ...
# 7038       1              0        1           1      24             1
# 7039       0              0        1           1      72             1
# 7040       0              0        1           1      11             0
# 7041       1              1        1           0       4             1
# 7042       1              0        0           0      66             1
#
#       MultipleLines  InternetService  OnlineSecurity  OnlineBackup  \
# ...

# %% [markdown]
# ## CORRELATION

# %%
Data.corr()
# Out:
#                     gender  SeniorCitizen   Partner  Dependents    tenure  \
# gender            1.000000      -0.001819 -0.001379    0.010349  0.005285
# SeniorCitizen    -0.001819       1.000000  0.016957   -0.210550  0.015683
# Partner          -0.001379       0.016957  1.000000    0.452269  0.381912
# Dependents        0.010349      -0.210550  0.452269    1.000000  0.163386
# tenure            0.005285       0.015683  0.381912    0.163386  1.000000
# PhoneService     -0.007515       0.008392  0.018397   -0.001078  0.007877
# MultipleLines    -0.006908       0.146287  0.142717   -0.024975  0.343673
# InternetService  -0.002236      -0.032160  0.000513    0.044030 -0.029835
# OnlineSecurity   -0.014899      -0.127937  0.150610    0.151198  0.327283
# OnlineBackup     -0.011920      -0.013355  0.153045    0.090231  0.372434
# DeviceProtection  0.001348      -0.021124  0.165614    0.079723  0.372669
# TechSupport      -0.006695      -0.151007  0.126488    0.132530  0.324729
# ...

# %%
Data = Data.drop(['MultipleLines','InternetService','StreamingTV','StreamingMovies'], axis = 1)

# %%
data = Data.drop(['Churn'],axis = 'columns')
data
# Out:
#       gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 0          0              0        1           0       1             0
# 1          1              0        0           0      34             1
# 2          1              0        0           0       2             1
# 3          1              0        0           0      45             0
# 4          0              0        0           0       2             1
# ...      ...            ...      ...         ...     ...           ...
# 7038       1              0        1           1      24             1
# 7039       0              0        1           1      72             1
# 7040       0              0        1           1      11             0
# 7041       1              1        1           0       4             1
# 7042       1              0        0           0      66             1
#
#       OnlineSecurity  OnlineBackup  DeviceProtection  TechSupport  Contract  \
# ...

# %%
data1 = Data['Churn']
data1
# Out:
# 0       0
# 1       0
# 2       1
# 3       0
# 4       1
#        ..
# 7038    0
# 7039    0
# 7040    0
# 7041    1
# 7042    0
# Name: Churn, Length: 7032, dtype: int64

# %%
data
# Out:
#       gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 0          0              0        1           0       1             0
# 1          1              0        0           0      34             1
# 2          1              0        0           0       2             1
# 3          1              0        0           0      45             0
# 4          0              0        0           0       2             1
# ...      ...            ...      ...         ...     ...           ...
# 7038       1              0        1           1      24             1
# 7039       0              0        1           1      72             1
# 7040       0              0        1           1      11             0
# 7041       1              1        1           0       4             1
# 7042       1              0        0           0      66             1
#
#       OnlineSecurity  OnlineBackup  DeviceProtection  TechSupport  Contract  \
# ...

# %% [markdown]
# ## TRAIN TEST SPLIT

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(data,data1, test_size=0.2, random_state=42)
X_train,X_test,y_train,y_test
# Out:
# (      gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
#  6030       0              0        0           0      43             0
#  3410       1              0        0           0       3             1
#  5483       0              0        1           0      55             1
#  5524       1              0        1           1      45             1
#  6337       0              0        1           1      55             1
#  ...      ...            ...      ...         ...     ...           ...
#  3778       1              0        0           0       3             1
#  5199       0              0        0           0      51             1
#  5235       1              0        0           0       9             1
#  5399       0              0        0           0      50             1
#  862        1              1        1           0      20             1
#
#        OnlineSecurity  OnlineBackup  DeviceProtection  TechSupport  Contract  \
# ...

# %% [markdown]
# ## LOGISTIC REGRESSION

# %%
from sklearn.linear_model import LogisticRegression

# %%
model1 = LogisticRegression()
model1.fit(X_train,y_train)
# Out:
# C:\Users\Ijas Ali.Machingal\anaconda3\envs\tensernew\Lib\site-packages\sklearn\linear_model\_logistic.py:470: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
model1.predict(X_test)
# Out:
# array([0, 0, 1, ..., 0, 0, 0])

# %%
model1.score(X_test,y_test)
# Out:
# 0.7839374555792467

# %% [markdown]
# ### SVM

# %%
from sklearn.svm import SVC

# %%
model2 = SVC()
model2.fit(X_train,y_train)
# Out:
# SVC()

# %%
model2.predict(X_test)
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
model2.score(X_test,y_test)
# Out:
# 0.7341862117981521

# %% [markdown]
# ### KERNAL

# %% [markdown]
# POLY

# %%
model3 = SVC(kernel = 'poly')
model3.fit(X_train, y_train)
# Out:
# SVC(kernel='poly')

# %%
model3.predict(X_test)
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
model3.score(X_test,y_test)
# Out:
# 0.7341862117981521

# %% [markdown]
# RBF

# %%
model4 = SVC(kernel='rbf')
model4.fit(X_train,y_train)
# Out:
# SVC()

# %%
model4.predict(X_test)
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
model4.score(X_test, y_test)
# Out:
# 0.7341862117981521

# %% [markdown]
# ### DECISION TREE CLASSIFIER

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
model5 = DecisionTreeClassifier()
model5.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
model5.predict(X_test)
# Out:
# array([0, 0, 1, ..., 0, 0, 0])

# %%
model5.score(X_test,y_test)
# Out:
# 0.7270788912579957

# %% [markdown]
# ### RANDOM FOREST CLASSIFIER

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
model6 = RandomForestClassifier()
model6.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
model6.predict(X_test)
# Out:
# array([0, 0, 1, ..., 0, 0, 0])

# %%
model6.score(X_test,y_test)
# Out:
# 0.7867803837953091

# %% [markdown]
# ### KNN

# %%
from sklearn.neighbors import KNeighborsClassifier

# %% [markdown]
# SCALING

# %%
data_copy = data.copy()
data_copy.isna().sum()
# Out:
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# dtype: int64

# %%
data_copy1 = data1.copy()

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
data_copy = pd.DataFrame(scaler.fit_transform(data_copy),columns = ['gender','SeniorCitizen','Partner', 'Dependents', 'tenure', 'PhoneService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport', 'Contract', 'PaperlessBilling', 'PaymentMethod', 'MonthlyCharges', 'TotalCharges'])
data_copy
# Out:
#         gender  SeniorCitizen   Partner  Dependents    tenure  PhoneService  \
# 0    -1.009430      -0.440327  1.035617   -0.652305 -1.280248     -3.056334
# 1     0.990658      -0.440327 -0.965608   -0.652305  0.064303      0.327189
# 2     0.990658      -0.440327 -0.965608   -0.652305 -1.239504      0.327189
# 3     0.990658      -0.440327 -0.965608   -0.652305  0.512486     -3.056334
# 4    -1.009430      -0.440327 -0.965608   -0.652305 -1.239504      0.327189
# ...        ...            ...       ...         ...       ...           ...
# 7027  0.990658      -0.440327  1.035617    1.533025 -0.343137      0.327189
# 7028 -1.009430      -0.440327  1.035617    1.533025  1.612573      0.327189
# 7029 -1.009430      -0.440327  1.035617    1.533025 -0.872808     -3.056334
# 7030  0.990658       2.271039  1.035617   -0.652305 -1.158016      0.327189
# 7031  0.990658      -0.440327 -0.965608   -0.652305  1.368109      0.327189
#
# ...

# %%
xtrain,xtest,ytrain,ytest = train_test_split(data_copy,data_copy1, test_size=0.2, random_state= 42)

# %%
knn = KNeighborsClassifier(n_neighbors=4)
knn.fit(xtrain,ytrain)
knn.score(xtest,ytest)
# Out:
# 0.7562189054726368

# %% [markdown]
# ACCURACY RATE TABLE

# %%
accuracy_rate = []
for i in range(1,40):
    knn = KNeighborsClassifier(n_neighbors=i)
    knn.fit(xtrain,ytrain)
    score = knn.score(xtest,ytest)
    accuracy_rate.append(score)

# %%
accuracy_rate
# Out:
# [0.7142857142857143,
#  0.749822316986496,
#  0.7292110874200426,
#  0.7562189054726368,
#  0.744136460554371,
#  0.749822316986496,
#  0.7590618336886994,
#  0.7690120824449183,
#  0.7604832977967306,
#  0.7775408670931059,
#  0.7718550106609808,
#  0.7739872068230277,
#  0.7718550106609808,
#  0.7690120824449183,
#  0.7668798862828714,
#  0.7718550106609808,
#  0.7626154939587776,
#  0.7711442786069652,
#  0.7626154939587776,
#  0.7683013503909026,
#  0.767590618336887,
#  0.767590618336887,
#  0.7661691542288557,
#  0.7704335465529495,
#  0.7626154939587776,
#  0.7690120824449183,
#  0.7647476901208244,
#  0.7683013503909026,
#  0.7690120824449183,
#  0.7768301350390903,
#  0.7746979388770433,
#  0.7768301350390903,
#  0.775408670931059,
#  0.7711442786069652,
#  0.7718550106609808,
#  0.7697228144989339,
#  0.7711442786069652,
#  0.7683013503909026,
#  0.7718550106609808]

# %%
most_accuracy = accuracy_rate.index(max(accuracy_rate)) + 1
most_accuracy
# Out:
# 10

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12,7))
plt.plot(range(1,40),accuracy_rate,color = 'blue',marker = 'o', linestyle = ':', markerfacecolor = 'red', markersize = 8)
plt.title('Accuracy vs K vlaue')
plt.xlabel('K value')
plt.ylabel('Accuracy')
# Out:
# Text(0, 0.5, 'Accuracy')

# %% [markdown]
# ERROR RATE TABLE

# %%
import numpy as np
error_rate = []
for i in range(1,40):
    knn = KNeighborsClassifier(n_neighbors=i)
    knn.fit(xtrain,ytrain)
    predict = knn.predict(xtest)
    error_rate.append(np.mean(predict != ytest))

# %%
error_rate
# Out:
# [np.float64(0.2857142857142857),
#  np.float64(0.2501776830135039),
#  np.float64(0.27078891257995735),
#  np.float64(0.24378109452736318),
#  np.float64(0.255863539445629),
#  np.float64(0.2501776830135039),
#  np.float64(0.24093816631130063),
#  np.float64(0.23098791755508175),
#  np.float64(0.23951670220326937),
#  np.float64(0.2224591329068941),
#  np.float64(0.2281449893390192),
#  np.float64(0.2260127931769723),
#  np.float64(0.2281449893390192),
#  np.float64(0.23098791755508175),
#  np.float64(0.23312011371712865),
#  np.float64(0.2281449893390192),
#  np.float64(0.23738450604122247),
#  np.float64(0.22885572139303484),
#  np.float64(0.23738450604122247),
#  np.float64(0.23169864960909736),
#  np.float64(0.232409381663113),
#  np.float64(0.232409381663113),
#  np.float64(0.23383084577114427),
#  np.float64(0.22956645344705046),
#  np.float64(0.23738450604122247),
#  np.float64(0.23098791755508175),
#  np.float64(0.23525230987917556),
#  np.float64(0.23169864960909736),
# ...

# %%
min_error = error_rate.index(min(error_rate))+ 1
min_error
# Out:
# 10

# %%
plt.figure(figsize=(12,7))
plt.plot(range(1,40),error_rate,color = 'red', linestyle = '--', marker = 'o', markerfacecolor = 'blue', markersize = 8)
plt.title('Error vs K value')
plt.xlabel("K value")
plt.ylabel('Error rate')
# Out:
# Text(0, 0.5, 'Error rate')

# %%
model7 = KNeighborsClassifier(n_neighbors=10)
model7.fit(X_train,y_train)
model7.predict(X_test)
# Out:
# array([0, 0, 1, ..., 0, 0, 0])

# %%
model7.score(X_test,y_test)
# Out:
# 0.7896233120113717

# %% [markdown]
# ## Confusion Matrix(KNN)

# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import seaborn as sn
from sklearn.metrics import confusion_matrix

# %%
cm = confusion_matrix(model7.predict(X_test),y_test)
cm
# Out:
# array([[972, 235],
#        [ 61, 139]])

# %%
sn.heatmap(cm, annot= True)
plt.xlabel('Predict')
plt.ylabel('Truth')
# Out:
# Text(50.722222222222214, 0.5, 'Truth')

# %% [markdown]
# ## Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB
model8 = GaussianNB()
model8.fit(X_train,y_train)
model8.predict(X_test)
# Out:
# array([0, 0, 1, ..., 0, 0, 0])

# %%
model8.score(X_test,y_test)
# Out:
# 0.7327647476901208

# %% [markdown]
# ## XG_Boost

# %%
# !pip install xgboost
# Out:
# ...
#   Using cached xgboost-3.0.5-py3-none-win_amd64.whl.metadata (2.1 kB)
# ...
#    ---------------------------------------- 0.0/56.8 MB ? eta -:--:--
#    ---------------------------------------- 0.3/56.8 MB ? eta -:--:--
#     --------------------------------------- 0.8/56.8 MB 2.6 MB/s eta 0:00:22
#    - -------------------------------------- 1.8/56.8 MB 3.4 MB/s eta 0:00:17
#    -- ------------------------------------- 2.9/56.8 MB 4.1 MB/s eta 0:00:14
#    --- ------------------------------------ 4.5/56.8 MB 4.9 MB/s eta 0:00:11
#    ---- ----------------------------------- 6.6/56.8 MB 5.9 MB/s eta 0:00:09
#    ----- ---------------------------------- 7.6/56.8 MB 6.0 MB/s eta 0:00:09
#    ------ --------------------------------- 8.9/56.8 MB 5.8 MB/s eta 0:00:09
#    ------- -------------------------------- 10.0/56.8 MB 5.6 MB/s eta 0:00:09
#    ------- -------------------------------- 10.7/56.8 MB 5.5 MB/s eta 0:00:09
# ...

# %%
from xgboost import XGBClassifier
model9 = XGBClassifier()
model9.fit(X_train,y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               feature_weights=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=None, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=None,
#               n_jobs=None, num_parallel_tree=None, ...)

# %%
model9.predict(X_test)
# Out:
# array([0, 0, 1, ..., 0, 0, 0])

# %%
model9.score(X_test,y_test)
# Out:
# 0.7782515991471215

# %% [markdown]
# ## VISUALIZATION

# %%
sn.countplot(data = Data, x = Data['SeniorCitizen'], hue='Churn')
plt.title("Senior Citizen Churn Distribution")
# Out:
# Text(0.5, 1.0, 'Senior Citizen Churn Distribution')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.countplot(x='Churn', data=Data, palette='Set2')
plt.title('Customer Churn Distribution')
plt.xlabel('Churn')
plt.ylabel('Count')
# Out:
# C:\Users\Ijas Ali.Machingal\AppData\Local\Temp\ipykernel_16684\3446485976.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Churn', data=Data, palette='Set2')
# Text(0, 0.5, 'Count')

# %%
sns.boxplot(x='Churn', y='MonthlyCharges', data=Data, palette='Set3')
plt.title('Monthly Charges vs Churn')
plt.xlabel('Churn')
plt.ylabel('Monthly Charges')
plt.show()
# Out:
# C:\Users\Ijas Ali.Machingal\AppData\Local\Temp\ipykernel_16684\4171544590.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Churn', y='MonthlyCharges', data=Data, palette='Set3')

# %%
sns.histplot(data=Data, x='tenure', hue='Churn', kde=True, multiple='stack', palette='coolwarm')
plt.title('Tenure Distribution by Churn')
plt.xlabel('Tenure (Months)')
plt.ylabel('Count')
plt.show()

# %%
contract_churn = pd.crosstab(Data['Contract'], Data['Churn'])
contract_churn.plot(kind='bar', stacked=True, colormap='viridis')
plt.title('Churn by Contract Type')
plt.xlabel('Contract Type')
plt.ylabel('Number of Customers')
plt.legend(title='Churn')
plt.show()
